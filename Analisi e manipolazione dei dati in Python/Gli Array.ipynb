# %%
import numpy as np

# %%
# commento 1
# commento 2
'''
 commento 3 
 su 
 più righe 
'''
# Out:
# '\n commento 3 \n su \n più righe \n'

# %% [markdown]
# # commento
#
# '''
# commento
#  su
#  più righe
# '''

# %%
x = np.array([1,2,3,4,5])

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y = np.array([[1,2],[3,4],[5,6]])

# %%
y
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
x[0]
# Out:
# 1

# %%
y[1,1]
# Out:
# 4
